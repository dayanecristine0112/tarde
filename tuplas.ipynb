# %% [markdown]
# Crie uma tupla com 4 números inteiros e exiba o segundo número

# %%
tupla_num =(10,20,30,40) 
print(tupla_num[1])
# Out:
# tupla_num{1}

# %% [markdown]
# .Crie duas tuplas com diferentes tipos de dados (ex: números e strings). Imprima o index 2 da tupla de números e o index 3 da tupla de string no mesmo print.

# %%
num = (5,10,15,20) 
nomes = ("Dayane" , "victor" , "thais","lais")
print(num[2], nomes[3])
